# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
from pylab import rcParams

import scipy
from scipy.stats.stats import pearsonr

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8, 4
plt.style.use('seaborn-whitegrid')

# %%
address ='C:/Users/abhir/Desktop/Python/Python_Data_Science/Python_Data_Science/Exercise Files/Ch01/01_05/mtcars.csv'
cars=pd.read_csv(address)
cars.columns=['carname','mpg','cyl','dsp','hp','drat','wt','qsec','vs','am','gear','carb']
sb.pairplot(cars)

# %%
X = cars[['mpg', 'hp', 'qsec','wt']]
sb.pairplot(X)

# %%
mpg = cars['mpg'] 
hp = cars['hp'] 
qsec = cars['qsec'] 
wt = cars['wt']

pearsonr_coefficient, p_value = pearsonr(mpg, qsec)
print 'PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient)
# Out:
#   File "<ipython-input-13-2ac8e0d5cd7a>", line 7
#     print 'PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient)
#                                                  ^
# SyntaxError: invalid syntax

# %%
pearsonr_coefficient, p_value = pearsonr(mpg, wt)
print 'PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient)
# Out:
#   File "<ipython-input-14-83b6878e3bad>", line 2
#     print 'PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient)
#                                                  ^
# SyntaxError: invalid syntax

# %%
corr = X.corr()
corr
# Out:
#            mpg        hp      qsec        wt
# mpg   1.000000 -0.776168  0.418684 -0.867659
# hp   -0.776168  1.000000 -0.708223  0.658748
# qsec  0.418684 -0.708223  1.000000 -0.174716
# wt   -0.867659  0.658748 -0.174716  1.000000

# %%
sb.heatmap(corr,xticklabels=corr.columns.values, yticklabels=corr.columns.values)
